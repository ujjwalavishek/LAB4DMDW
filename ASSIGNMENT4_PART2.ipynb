# %% [markdown]
# <a href="https://colab.research.google.com/github/ujjwalvishek/LAB4DMDW/blob/main/ASSIGNMENT4_PART2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv(r"https://raw.githubusercontent.com/archana1822/DMDW-Lab/main/Toyota.csv")
dataset
# Out:
#       Unnamed: 0  Price   Age     KM  ... Automatic    CC  Doors  Weight
# 0              0  13500  23.0  46986  ...         0  2000  three    1165
# 1              1  13750  23.0  72937  ...         0  2000      3    1165
# 2              2  13950  24.0  41711  ...         0  2000      3    1165
# 3              3  14950  26.0  48000  ...         0  2000      3    1165
# 4              4  13750  30.0  38500  ...         0  2000      3    1170
# ...          ...    ...   ...    ...  ...       ...   ...    ...     ...
# 1431        1431   7500   NaN  20544  ...         0  1300      3    1025
# 1432        1432  10845  72.0     ??  ...         0  1300      3    1015
# 1433        1433   8500   NaN  17016  ...         0  1300      3    1015
# 1434        1434   7250  70.0     ??  ...         0  1300      3    1015
# 1435        1435   6950  76.0      1  ...         0  1600      5    1114
#
# [1436 rows x 11 columns]

# %%
dataset.dropna(axis=0,inplace=True)
dataset
# Out:
#       Unnamed: 0  Price   Age     KM  ... Automatic    CC  Doors  Weight
# 0              0  13500  23.0  46986  ...         0  2000  three    1165
# 1              1  13750  23.0  72937  ...         0  2000      3    1165
# 3              3  14950  26.0  48000  ...         0  2000      3    1165
# 4              4  13750  30.0  38500  ...         0  2000      3    1170
# 5              5  12950  32.0  61000  ...         0  2000      3    1170
# ...          ...    ...   ...    ...  ...       ...   ...    ...     ...
# 1425        1425   7950  80.0     ??  ...         0  1300      4    1000
# 1429        1429   8950  78.0  24000  ...         1  1300      5    1065
# 1430        1430   8450  80.0  23000  ...         0  1300      3    1015
# 1432        1432  10845  72.0     ??  ...         0  1300      3    1015
# 1435        1435   6950  76.0      1  ...         0  1600      5    1114
#
# [1111 rows x 11 columns]

# %%
dataset.shape
# Out:
# (1111, 11)

# %%
dataset.head()
# Out:
#    Unnamed: 0  Price   Age     KM  ... Automatic    CC  Doors  Weight
# 0           0  13500  23.0  46986  ...         0  2000  three    1165
# 1           1  13750  23.0  72937  ...         0  2000      3    1165
# 3           3  14950  26.0  48000  ...         0  2000      3    1165
# 4           4  13750  30.0  38500  ...         0  2000      3    1170
# 5           5  12950  32.0  61000  ...         0  2000      3    1170
#
# [5 rows x 11 columns]

# %%
sns.set(style='darkgrid')
sns.regplot(x=dataset['Age'],y=dataset['Price'])

# %%
sns.set(style='darkgrid')
sns.regplot(x=dataset['Age'],y=dataset['Price'],marker='*',fit_reg=False)

# %%
sns.distplot(dataset['Age'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(dataset['Age'],kde=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(dataset['Age'],kde=False,bins=5)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.countplot(x="FuelType",data=dataset)

# %%
sns.countplot(x='FuelType',data=dataset,hue='Automatic')

# %%
sns.boxplot(y=dataset['Price'])

# %%
sns.boxplot(x=dataset['FuelType'],y=dataset['Price'])

# %%
sns.boxplot(x='FuelType',y=dataset['Price'],hue='Automatic',data=dataset)

# %%
sns.boxplot(x=dataset['FuelType'],y=dataset['Price'],hue='Automatic',data=dataset)

# %%
f,(ax_box,ax_hist) = plt.subplots(2,gridspec_kw={'height_ratios':(.20,.80)})

# %%
f,(ax_box,ax_hist) = plt.subplots(2,gridspec_kw={'height_ratios':(.20,.80)})
sns.boxplot(dataset['Price'],ax=ax_box)
sns.distplot(dataset['Price'],ax=ax_hist,kde=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.pairplot(dataset,kind='countplot',hue='FuelType')
plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
